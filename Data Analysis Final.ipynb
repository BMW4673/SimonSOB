# %%
# Import pandas and load file, verifying output and inspect
import pandas as pd
df = pd.read_excel('Salaries.xlsx', engine='openpyxl')
print(f'Print Table Header with First Five Rows\n')
print(df.head())
print(- * 20)
print(f'Print Table Info with column headers and type\n')
df.info()
print()
print(f'Print Table Analysis\n')
df.describe()
# Out:
#   Cell In[40], line 6
#     print(- * 20)
#             ^
# SyntaxError: invalid syntax
